# %%
# Run the wumpus player with Baysian network and SAT Solver

import time
start_time = time.time()
# !gridrunner --world WumpusWorld --entry wumpus-usage:OnlineDFSPlayer --horizon 200
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------- Playing on world: ----------
# {"size": [4, 4], "hunters": [[0, 0, "N"]], "wumpuses": [[2, 3]], "exits": [[0, 0]], "golds": [[2, 3]]}
# ----------------------------------------
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @^│   │   │   │
# └───┴───┴───┴───┘
# Step 0: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @^│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 1: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @^│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 2: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │ @^│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 3: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │ @^│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 4: agent Hunter_3df0399d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │ @>│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 5: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │ @>│   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 6: agent Hunter_3df0399d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │ @V│   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 7: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │ @V│   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 8: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │ @V│   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 9: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │ @V│   │   │
# └───┴───┴───┴───┘
# Step 10: agent Hunter_3df0399d executing LEFT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │ @>│   │   │
# └───┴───┴───┴───┘
# Step 11: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │ @>│   │
# └───┴───┴───┴───┘
# Step 12: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │ @>│
# └───┴───┴───┴───┘
# Step 13: agent Hunter_3df0399d executing LEFT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │ @^│
# └───┴───┴───┴───┘
# Step 14: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │ @^│
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 15: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │ @^│
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 16: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │ @^│
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 17: agent Hunter_3df0399d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │ @>│
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 18: agent Hunter_3df0399d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │ @V│
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 19: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │ @V│
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 20: agent Hunter_3df0399d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │ @<│
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 21: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │ @<│   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 22: agent Hunter_3df0399d executing LEFT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │ @V│   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 23: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │ @V│   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 24: agent Hunter_3df0399d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │ @<│   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 25: agent Hunter_3df0399d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │ @^│   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 26: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │WG │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │ @^│   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 27: agent Hunter_3df0399d executing SHOOT -> reward -10
# ┌───┬───┬───┬───┐
# │   │   │ G │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │ @^│   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 28: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │ G │   │
# │   │   │ @^│   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 29: agent Hunter_3df0399d executing GRAB -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │ @^│   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 30: agent Hunter_3df0399d executing LEFT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │ @<│   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 31: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │ @<│   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 32: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │ @<│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 33: agent Hunter_3df0399d executing LEFT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │ @V│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 34: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @V│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 35: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @V│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 36: agent Hunter_3df0399d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @V│   │   │   │
# └───┴───┴───┴───┘
# Step 37: agent Hunter_3df0399d executing CLIMB -> reward 999
# The agent Hunter_3df0399d succeeded!
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @V│   │   │   │
# └───┴───┴───┴───┘
# Episode terminated with a reward of 953 for agent Hunter_3df0399d
# --- 1.3810548782348633 seconds ---
