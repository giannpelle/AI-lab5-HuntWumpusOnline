# %%
# Run the wumpus player with Baysian network and SAT Solver

import time
start_time = time.time()
# !gridrunner --world WumpusWorld --entry wumpus-usage:OnlineDFSPlayer --horizon 200
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------- Playing on world: ----------
# {"size": [4, 4], "hunters": [[0, 0, "N"]], "pits": [[3, 1], [0, 2], [2, 2]], "wumpuses": [[0, 1]], "exits": [[0, 0]], "golds": [[0, 2]]}
# ----------------------------------------
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │W  │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @^│   │   │   │
# └───┴───┴───┴───┘
# Step 0: agent Hunter_5c31429d executing SHOOT -> reward -10
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @^│   │   │   │
# └───┴───┴───┴───┘
# Step 1: agent Hunter_5c31429d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │ @^│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 2: agent Hunter_5c31429d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │ @>│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 3: agent Hunter_5c31429d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │ @V│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 4: agent Hunter_5c31429d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @V│   │   │   │
# └───┴───┴───┴───┘
# Step 5: agent Hunter_5c31429d executing LEFT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @>│   │   │   │
# └───┴───┴───┴───┘
# Step 6: agent Hunter_5c31429d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │ @>│   │   │
# └───┴───┴───┴───┘
# Step 7: agent Hunter_5c31429d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │ @>│   │
# └───┴───┴───┴───┘
# Step 8: agent Hunter_5c31429d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │ @>│
# └───┴───┴───┴───┘
# Step 9: agent Hunter_5c31429d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │ @V│
# └───┴───┴───┴───┘
# Step 10: agent Hunter_5c31429d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │ @<│
# └───┴───┴───┴───┘
# Step 11: agent Hunter_5c31429d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │ @<│   │
# └───┴───┴───┴───┘
# Step 12: agent Hunter_5c31429d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │ @^│   │
# └───┴───┴───┴───┘
# Step 13: agent Hunter_5c31429d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │ @^│   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 14: agent Hunter_5c31429d executing LEFT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │ @<│   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 15: agent Hunter_5c31429d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │ @<│   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 16: agent Hunter_5c31429d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │ @^│   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 17: agent Hunter_5c31429d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │ @^│   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 18: agent Hunter_5c31429d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │ @>│   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 19: agent Hunter_5c31429d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │ @V│   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 20: agent Hunter_5c31429d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │ @V│   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 21: agent Hunter_5c31429d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │ @V│   │   │
# └───┴───┴───┴───┘
# Step 22: agent Hunter_5c31429d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │ @<│   │   │
# └───┴───┴───┴───┘
# Step 23: agent Hunter_5c31429d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @<│   │   │   │
# └───┴───┴───┴───┘
# Step 24: agent Hunter_5c31429d executing CLIMB -> reward -1
# The agent Hunter_5c31429d succeeded!
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │ GP│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @<│   │   │   │
# └───┴───┴───┴───┘
# Episode terminated with a reward of -34 for agent Hunter_5c31429d
# --- 9.357553958892822 seconds ---
