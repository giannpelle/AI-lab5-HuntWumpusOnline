# %%
import time
start_time = time.time()
# !gridrunner --world WumpusWorld --entry wumpus-usage-only-safe:OnlineDFSPlayer worlds/error3.json --horizon 200
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ┌───┬───┬───┬───┬───┬───┬───┐
# │  P│   │  P│   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │  P│   │   │   │ G │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │W  │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │  P│   │   │   │  P│   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │  P│   │  P│   │  P│
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │  P│
# │ @^│   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┘
# Step 0: agent Hunter_76c960a9 executing MOVE -> reward -1
# ┌───┬───┬───┬───┬───┬───┬───┐
# │  P│   │  P│   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │  P│   │   │   │ G │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# ...

# %%
import time
start_time = time.time()

for i in range(10):
    start_time2 = time.time()
    # %run test_hunter wumpus-usage-only-safe:OnlineDFSPlayer --random 1000
    print("--- %s seconds ---" % (time.time() - start_time2))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage-only-safe:OnlineDFSPlayer: run 1000 episodes with average outcome of 210.758 dying 0 times (raised 0 exceptions).
# --- 11.880766868591309 seconds ---
# Player wumpus-usage-only-safe:OnlineDFSPlayer: run 1000 episodes with average outcome of 244.136 dying 0 times (raised 0 exceptions).
# --- 13.50698709487915 seconds ---
# Player wumpus-usage-only-safe:OnlineDFSPlayer: run 1000 episodes with average outcome of 207.183 dying 0 times (raised 0 exceptions).
# --- 12.343384027481079 seconds ---
# Player wumpus-usage-only-safe:OnlineDFSPlayer: run 1000 episodes with average outcome of 221.894 dying 0 times (raised 0 exceptions).
# --- 11.93963098526001 seconds ---
# Player wumpus-usage-only-safe:OnlineDFSPlayer: run 1000 episodes with average outcome of 219.413 dying 0 times (raised 0 exceptions).
# --- 13.158273220062256 seconds ---
# Player wumpus-usage-only-safe:OnlineDFSPlayer: run 1000 episodes with average outcome of 205.692 dying 0 times (raised 0 exceptions).
# ...

# %%
import time
start_time = time.time()

for i in range(10):
    start_time2 = time.time()
    # %run test_hunter wumpus-usage:OnlineDFSPlayer --random 100
    print("--- %s seconds ---" % (time.time() - start_time2))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage:OnlineDFSPlayer: run 100 episodes with average outcome of 75.54 dying 17 times (raised 0 exceptions).
# --- 77.1344850063324 seconds ---
# Player wumpus-usage:OnlineDFSPlayer: run 100 episodes with average outcome of 131.8 dying 23 times (raised 0 exceptions).
# --- 88.90150785446167 seconds ---
# Player wumpus-usage:OnlineDFSPlayer: run 100 episodes with average outcome of 64.21 dying 21 times (raised 0 exceptions).
# --- 60.97034978866577 seconds ---
# Player wumpus-usage:OnlineDFSPlayer: run 100 episodes with average outcome of 60.71 dying 28 times (raised 0 exceptions).
# --- 64.29741215705872 seconds ---
# Player wumpus-usage:OnlineDFSPlayer: run 100 episodes with average outcome of 69.37 dying 23 times (raised 0 exceptions).
# --- 77.33378386497498 seconds ---
# Player wumpus-usage:OnlineDFSPlayer: run 100 episodes with average outcome of 149.17 dying 15 times (raised 0 exceptions).
# --- 32.982479095458984 seconds ---
# ...

# %%
import time
start_time = time.time()
for i in range(5):
    # !gridrunner --world WumpusWorld --entry wumpus-usage-no-SAT:OnlineDFSPlayer worlds/error1.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage-no-SAT:OnlineDFSPlayer worlds/error3.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage-no-SAT:OnlineDFSPlayer worlds/error4.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage-no-SAT:OnlineDFSPlayer worlds/error5.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage-no-SAT:OnlineDFSPlayer worlds/error6.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage-no-SAT:OnlineDFSPlayer worlds/error7.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage-no-SAT:OnlineDFSPlayer worlds/error8.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage-no-SAT:OnlineDFSPlayer worlds/error9.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage-no-SAT:OnlineDFSPlayer worlds/show1.json --horizon 200 --noshow
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ┌───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │  P│  P│  P│   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │  P│   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │  P│  P│  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │ G │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │W  │   │   │  P│   │   │
# │ @^│   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┘
# Step 0: agent Hunter_e8e188a6 executing SHOOT -> reward -10
# Step 1: agent Hunter_e8e188a6 executing MOVE -> reward -1
# Step 2: agent Hunter_e8e188a6 executing MOVE -> reward -1
# Step 3: agent Hunter_e8e188a6 executing MOVE -> reward -1
# ...

# %%
import time
start_time = time.time()
for i in range(5):
    # !gridrunner --world WumpusWorld --entry wumpus-usage:OnlineDFSPlayer worlds/error1.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage:OnlineDFSPlayer worlds/error3.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage:OnlineDFSPlayer worlds/error4.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage:OnlineDFSPlayer worlds/error5.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage:OnlineDFSPlayer worlds/error6.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage:OnlineDFSPlayer worlds/error7.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage:OnlineDFSPlayer worlds/error8.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage:OnlineDFSPlayer worlds/error9.json --horizon 200 --noshow
    #print("--- %s seconds ---" % (time.time() - start_time))
    #start_time = time.time()
    # !gridrunner --world WumpusWorld --entry wumpus-usage:OnlineDFSPlayer worlds/show1.json --horizon 200 --noshow
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ┌───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │  P│  P│  P│   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │  P│   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │  P│  P│  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │ G │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │W  │   │   │  P│   │   │
# │ @^│   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┘
# Step 0: agent Hunter_9cc151be executing SHOOT -> reward -10
# Step 1: agent Hunter_9cc151be executing MOVE -> reward -1
# Step 2: agent Hunter_9cc151be executing MOVE -> reward -1
# Step 3: agent Hunter_9cc151be executing MOVE -> reward -1
# ...

# %%
for i in range(4, 9):
    for j in [60, 70, 72, 74, 76, 78, 80, 90]:
        print("start_time = time.time()")
        print(f"%run test_hunter_{i}x{i} wumpus-usage_{j}:OnlineDFSPlayer --log log_{i}x{i}_{j}.log --random 2000")
        print(f'print("{i}{i}_{j}--- %s seconds ---" % (time.time() - start_time))')

# %%
import time
start_time = time.time()
# %run test_hunter_4x4 wumpus-usage_60:OnlineDFSPlayer --log log_4x4_60.log --random 2000
print("44_60--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_60:OnlineDFSPlayer: run 2000 episodes with average outcome of 344.2015 dying 181 times (raised 0 exceptions).
# 44_60--- 135.24252200126648 seconds ---

# %%
start_time = time.time()
# %run test_hunter_4x4 wumpus-usage_70:OnlineDFSPlayer --log log_4x4_70.log --random 2000
print("44_70--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_70:OnlineDFSPlayer: run 2000 episodes with average outcome of 334.069 dying 32 times (raised 0 exceptions).
# 44_70--- 98.80950927734375 seconds ---

# %%
start_time = time.time()
# %run test_hunter_4x4 wumpus-usage_72:OnlineDFSPlayer --log log_4x4_72.log --random 2000
print("44_72--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_72:OnlineDFSPlayer: run 2000 episodes with average outcome of 351.238 dying 45 times (raised 0 exceptions).
# 44_72--- 98.4511559009552 seconds ---

# %%
start_time = time.time()
# %run test_hunter_4x4 wumpus-usage_74:OnlineDFSPlayer --log log_4x4_74.log --random 2000
print("44_74--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_74:OnlineDFSPlayer: run 2000 episodes with average outcome of 337.5545 dying 36 times (raised 0 exceptions).
# 44_74--- 99.29040908813477 seconds ---

# %%
start_time = time.time()
# %run test_hunter_4x4 wumpus-usage_76:OnlineDFSPlayer --log log_4x4_76.log --random 2000
print("44_76--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_76:OnlineDFSPlayer: run 2000 episodes with average outcome of 353.359 dying 36 times (raised 0 exceptions).
# 44_76--- 94.00246596336365 seconds ---

# %%
start_time = time.time()
# %run test_hunter_4x4 wumpus-usage_78:OnlineDFSPlayer --log log_4x4_78.log --random 2000
print("44_78--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_78:OnlineDFSPlayer: run 2000 episodes with average outcome of 324.2475 dying 45 times (raised 0 exceptions).
# 44_78--- 102.17459011077881 seconds ---

# %%
start_time = time.time()
# %run test_hunter_4x4 wumpus-usage_80:OnlineDFSPlayer --log log_4x4_80.log --random 2000
print("44_80--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_80:OnlineDFSPlayer: run 2000 episodes with average outcome of 335.1935 dying 0 times (raised 0 exceptions).
# 44_80--- 91.52363801002502 seconds ---

# %%
start_time = time.time()
# %run test_hunter_4x4 wumpus-usage_90:OnlineDFSPlayer --log log_4x4_90.log --random 2000
print("44_90--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_90:OnlineDFSPlayer: run 2000 episodes with average outcome of 348.5495 dying 0 times (raised 0 exceptions).
# 44_90--- 88.03133416175842 seconds ---

# %%
start_time = time.time()
# %run test_hunter_5x5 wumpus-usage_60:OnlineDFSPlayer --log log_5x5_60.log --random 2000
print("55_60--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_60:OnlineDFSPlayer: run 2000 episodes with average outcome of 234.392 dying 290 times (raised 0 exceptions).
# 55_60--- 2774.5426890850067 seconds ---

# %%
start_time = time.time()
# %run test_hunter_5x5 wumpus-usage_70:OnlineDFSPlayer --log log_5x5_70.log --random 2000
print("55_70--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_70:OnlineDFSPlayer: run 2000 episodes with average outcome of 256.19 dying 96 times (raised 0 exceptions).
# 55_70--- 1233.1127979755402 seconds ---

# %%
start_time = time.time()
# %run test_hunter_5x5 wumpus-usage_72:OnlineDFSPlayer --log log_5x5_72.log --random 2000
print("55_72--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_72:OnlineDFSPlayer: run 2000 episodes with average outcome of 276.18 dying 72 times (raised 0 exceptions).
# 55_72--- 625.5812499523163 seconds ---

# %%
start_time = time.time()
# %run test_hunter_5x5 wumpus-usage_74:OnlineDFSPlayer --log log_5x5_74.log --random 2000
print("55_74--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_74:OnlineDFSPlayer: run 2000 episodes with average outcome of 265.522 dying 67 times (raised 0 exceptions).
# 55_74--- 757.1692178249359 seconds ---

# %%
start_time = time.time()
# %run test_hunter_5x5 wumpus-usage_76:OnlineDFSPlayer --log log_5x5_76.log --random 2000
print("55_76--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_76:OnlineDFSPlayer: run 2000 episodes with average outcome of 251.7265 dying 84 times (raised 0 exceptions).
# 55_76--- 669.627375125885 seconds ---

# %%
start_time = time.time()
# %run test_hunter_5x5 wumpus-usage_78:OnlineDFSPlayer --log log_5x5_78.log --random 2000
print("55_78--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_78:OnlineDFSPlayer: run 2000 episodes with average outcome of 268.075 dying 71 times (raised 0 exceptions).
# 55_78--- 601.3671188354492 seconds ---

# %%
start_time = time.time()
# %run test_hunter_5x5 wumpus-usage_80:OnlineDFSPlayer --log log_5x5_80.log --random 2000
print("55_80--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_80:OnlineDFSPlayer: run 2000 episodes with average outcome of 264.608 dying 0 times (raised 0 exceptions).
# 55_80--- 417.5069069862366 seconds ---

# %%
start_time = time.time()
# %run test_hunter_5x5 wumpus-usage_90:OnlineDFSPlayer --log log_5x5_90.log --random 2000
print("55_90--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_90:OnlineDFSPlayer: run 2000 episodes with average outcome of 263.3805 dying 0 times (raised 0 exceptions).
# 55_90--- 421.44931983947754 seconds ---

# %%
start_time = time.time()
# %run test_hunter_6x6 wumpus-usage_60:OnlineDFSPlayer --log log_6x6_60.log --random 2000
print("66_60--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_60:OnlineDFSPlayer: run 2000 episodes with average outcome of 102.904 dying 390 times (raised 0 exceptions).
# 66_60--- 2189.7674827575684 seconds ---

# %%
start_time = time.time()
# %run test_hunter_6x6 wumpus-usage_70:OnlineDFSPlayer --log log_6x6_70.log --random 2000
print("66_70--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_70:OnlineDFSPlayer: run 2000 episodes with average outcome of 182.7685 dying 134 times (raised 0 exceptions).
# 66_70--- 1577.5208661556244 seconds ---

# %%
start_time = time.time()
# %run test_hunter_6x6 wumpus-usage_72:OnlineDFSPlayer --log log_6x6_72.log --random 2000
print("66_72--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_72:OnlineDFSPlayer: run 2000 episodes with average outcome of 193.095 dying 120 times (raised 0 exceptions).
# 66_72--- 1342.230661869049 seconds ---

# %%
start_time = time.time()
# %run test_hunter_6x6 wumpus-usage_74:OnlineDFSPlayer --log log_6x6_74.log --random 1000
print("66_74--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_74:OnlineDFSPlayer: run 1000 episodes with average outcome of 180.433 dying 64 times (raised 0 exceptions).
# 66_74--- 741.0668590068817 seconds ---

# %%
start_time = time.time()
# %run test_hunter_6x6 wumpus-usage_76:OnlineDFSPlayer --log log_6x6_76.log --random 1000
print("66_76--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_76:OnlineDFSPlayer: run 1000 episodes with average outcome of 188.972 dying 50 times (raised 0 exceptions).
# 66_76--- 594.0920140743256 seconds ---

# %%
start_time = time.time()
# %run test_hunter_6x6 wumpus-usage_78:OnlineDFSPlayer --log log_6x6_78.log --random 1000
print("66_78--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_78:OnlineDFSPlayer: run 1000 episodes with average outcome of 159.818 dying 60 times (raised 0 exceptions).
# 66_78--- 705.7962770462036 seconds ---

# %%
start_time = time.time()
# %run test_hunter_6x6 wumpus-usage_80:OnlineDFSPlayer --log log_6x6_80.log --random 1000
print("66_80--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_80:OnlineDFSPlayer: run 1000 episodes with average outcome of 195.661 dying 0 times (raised 0 exceptions).
# 66_80--- 335.9840929508209 seconds ---

# %%
start_time = time.time()
# %run test_hunter_6x6 wumpus-usage_90:OnlineDFSPlayer --log log_6x6_90.log --random 1000
print("66_90--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_90:OnlineDFSPlayer: run 1000 episodes with average outcome of 207.721 dying 0 times (raised 0 exceptions).
# 66_90--- 352.1130952835083 seconds ---

# %%
start_time = time.time()
# %run test_hunter_7x7 wumpus-usage_60:OnlineDFSPlayer --log log_7x7_60.log --random 1000
print("77_60--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_60:OnlineDFSPlayer: run 1000 episodes with average outcome of -14.722 dying 249 times (raised 0 exceptions).
# 77_60--- 2130.0842430591583 seconds ---

# %%
start_time = time.time()
# %run test_hunter_7x7 wumpus-usage_70:OnlineDFSPlayer --log log_7x7_70.log --random 1000
print("77_70--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_70:OnlineDFSPlayer: run 1000 episodes with average outcome of 120.336 dying 87 times (raised 0 exceptions).
# 77_70--- 1169.665932893753 seconds ---

# %%
start_time = time.time()
# %run test_hunter_7x7 wumpus-usage_72:OnlineDFSPlayer --log log_7x7_72.log --random 1000
print("77_72--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_72:OnlineDFSPlayer: run 1000 episodes with average outcome of 126.244 dying 91 times (raised 0 exceptions).
# 77_72--- 1226.1647968292236 seconds ---

# %%
start_time = time.time()
# %run test_hunter_7x7 wumpus-usage_74:OnlineDFSPlayer --log log_7x7_74.log --random 1000
print("77_74--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_74:OnlineDFSPlayer: run 1000 episodes with average outcome of 153.147 dying 65 times (raised 0 exceptions).
# 77_74--- 401.33055114746094 seconds ---

# %%
start_time = time.time()
# %run test_hunter_7x7 wumpus-usage_76:OnlineDFSPlayer --log log_7x7_76.log --random 1000
print("77_76--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_76:OnlineDFSPlayer: run 1000 episodes with average outcome of 154.618 dying 58 times (raised 0 exceptions).
# 77_76--- 340.973424911499 seconds ---

# %%
start_time = time.time()
# %run test_hunter_7x7 wumpus-usage_78:OnlineDFSPlayer --log log_7x7_78.log --random 1000
print("77_78--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_78:OnlineDFSPlayer: run 1000 episodes with average outcome of 119.334 dying 89 times (raised 0 exceptions).
# 77_78--- 408.92881989479065 seconds ---

# %%
start_time = time.time()
# %run test_hunter_7x7 wumpus-usage_80:OnlineDFSPlayer --log log_7x7_80.log --random 1000
print("77_80--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_80:OnlineDFSPlayer: run 1000 episodes with average outcome of 164.555 dying 0 times (raised 0 exceptions).
# 77_80--- 159.83873891830444 seconds ---

# %%
start_time = time.time()
# %run test_hunter_7x7 wumpus-usage_90:OnlineDFSPlayer --log log_7x7_90.log --random 1000
print("77_90--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_90:OnlineDFSPlayer: run 1000 episodes with average outcome of 179.306 dying 0 times (raised 0 exceptions).
# 77_90--- 170.70918011665344 seconds ---

# %%
start_time = time.time()
# %run test_hunter_8x8 wumpus-usage_60:OnlineDFSPlayer --log log_8x8_60.log --random 1000
print("88_60--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_60:OnlineDFSPlayer: run 1000 episodes with average outcome of -56.109 dying 278 times (raised 0 exceptions).
# 88_60--- 1252.059553861618 seconds ---

# %%
start_time = time.time()
# %run test_hunter_8x8 wumpus-usage_70:OnlineDFSPlayer --log log_8x8_70.log --random 1000
print("88_70--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_70:OnlineDFSPlayer: run 1000 episodes with average outcome of 65.394 dying 97 times (raised 0 exceptions).
# 88_70--- 782.5566251277924 seconds ---

# %%
start_time = time.time()
# %run test_hunter_8x8 wumpus-usage_72:OnlineDFSPlayer --log log_8x8_72.log --random 1000
print("88_72--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_72:OnlineDFSPlayer: run 1000 episodes with average outcome of 47.048 dying 116 times (raised 0 exceptions).
# 88_72--- 711.3416037559509 seconds ---

# %%
start_time = time.time()
# %run test_hunter_8x8 wumpus-usage_74:OnlineDFSPlayer --log log_8x8_74.log --random 1000
print("88_74--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_74:OnlineDFSPlayer: run 1000 episodes with average outcome of 60.656 dying 103 times (raised 0 exceptions).
# 88_74--- 702.480406999588 seconds ---

# %%
start_time = time.time()
# %run test_hunter_8x8 wumpus-usage_76:OnlineDFSPlayer --log log_8x8_76.log --random 1000
print("88_76--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_76:OnlineDFSPlayer: run 1000 episodes with average outcome of 78.204 dying 97 times (raised 0 exceptions).
# 88_76--- 674.8602459430695 seconds ---

# %%
start_time = time.time()
# %run test_hunter_8x8 wumpus-usage_78:OnlineDFSPlayer --log log_8x8_78.log --random 1000
print("88_78--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_78:OnlineDFSPlayer: run 1000 episodes with average outcome of 85.63 dying 84 times (raised 0 exceptions).
# 88_78--- 674.3462898731232 seconds ---

# %%
start_time = time.time()
# %run test_hunter_8x8 wumpus-usage_80:OnlineDFSPlayer --log log_8x8_80.log --random 1000
print("88_80--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_80:OnlineDFSPlayer: run 1000 episodes with average outcome of 124.257 dying 0 times (raised 0 exceptions).
# 88_80--- 239.15585327148438 seconds ---

# %%
start_time = time.time()
# %run test_hunter_8x8 wumpus-usage_90:OnlineDFSPlayer --log log_8x8_90.log --random 1000
print("88_90--- %s seconds ---" % (time.time() - start_time))
# Out:
# Player wumpus-usage_90:OnlineDFSPlayer: run 1000 episodes with average outcome of 112.074 dying 0 times (raised 0 exceptions).
# 88_90--- 226.67356991767883 seconds ---
