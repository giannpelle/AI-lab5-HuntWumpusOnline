# %%
# Run the wumpus player with Baysian network and SAT Solver

import time
start_time = time.time()
# !gridrunner --world WumpusWorld --entry wumpus-usage:OnlineDFSPlayer --horizon 200
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------- Playing on world: ----------
# {"size": [4, 4], "hunters": [[0, 0, "N"]], "pits": [[2, 0], [3, 3]], "wumpuses": [[3, 0]], "exits": [[0, 0]], "golds": [[3, 2]]}
# ----------------------------------------
# ┌───┬───┬───┬───┐
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │ G │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │  P│W  │
# │ @^│   │   │   │
# └───┴───┴───┴───┘
# Step 0: agent Hunter_7c71455e executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │ G │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @^│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │  P│W  │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 1: agent Hunter_7c71455e executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │ G │
# │ @^│   │   │   │
# ├───┼───┼───┼───┤
# ...

# %%
# Run the wumpus player with Baysian network and no SAT Solver

import time
start_time = time.time()
# !gridrunner --world WumpusWorld --entry wumpus-usage-no-SAT:OnlineDFSPlayer --horizon 200
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------- Playing on world: ----------
# {"size": [4, 4], "hunters": [[0, 0, "N"]], "pits": [[3, 0], [1, 3], [2, 3]], "wumpuses": [[2, 3]], "exits": [[0, 0]], "golds": [[1, 3]]}
# ----------------------------------------
# ┌───┬───┬───┬───┐
# │   │ GP│W P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │ @^│   │   │   │
# └───┴───┴───┴───┘
# Step 0: agent Hunter_82d07c5e executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │ GP│W P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @^│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │  P│
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 1: agent Hunter_82d07c5e executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │ GP│W P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @^│   │   │   │
# ...

# %%
# Run the wumpus player without Bayesian network and without SAT Solver

import time
start_time = time.time()
# !gridrunner --world WumpusWorld --entry wumpus-usage-only-safe:OnlineDFSPlayer --horizon 200
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------- Playing on world: ----------
# {"size": [4, 4], "hunters": [[0, 0, "N"]], "pits": [[2, 2], [3, 2]], "wumpuses": [[0, 2]], "exits": [[0, 0]], "golds": [[2, 3]]}
# ----------------------------------------
# ┌───┬───┬───┬───┐
# │   │   │ G │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │W  │   │  P│  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @^│   │   │   │
# └───┴───┴───┴───┘
# Step 0: agent Hunter_3d31506d executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │ G │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │W  │   │  P│  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @^│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 1: agent Hunter_3d31506d executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │   │ G │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │W  │   │  P│  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# ...

# %%
# Run the wumpus player with Bayesian network and SAT Solver and Logger

import time
start_time = time.time()
# !gridrunner --world WumpusWorld --entry wumpus-usage-logger:OnlineDFSPlayer --horizon 200
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------- Playing on world: ----------
# {"size": [4, 4], "hunters": [[0, 0, "N"]], "pits": [[0, 2], [2, 2], [3, 3]], "wumpuses": [[2, 3]], "exits": [[0, 0]], "golds": [[1, 3]]}
# ----------------------------------------
# ┌───┬───┬───┬───┐
# │   │ G │W  │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │  P│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @^│   │   │   │
# └───┴───┴───┴───┘
# Step 0: agent Hunter_60a87c5e executing MOVE -> reward -1
# ┌───┬───┬───┬───┐
# │   │ G │W  │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │  P│   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @^│   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# └───┴───┴───┴───┘
# Step 1: agent Hunter_60a87c5e executing RIGHT -> reward -1
# ┌───┬───┬───┬───┐
# │   │ G │W  │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │  P│   │  P│   │
# │   │   │   │   │
# ...
